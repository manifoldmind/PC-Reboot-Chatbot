# %% [markdown]
# TARG: Превратить грязный пользовательский ввод в чистый список хостов, а затем в список объектов RebootTask.
#
# Например если пользак может ввести грязь:
#   ws-k534d, WS-K534F ,, ws-k534d , TEST-PC,

# %%
# SABX__input_parser.ipynb
# Цель: черновик разбора и нормализации входного списка хостов.
#
# Здесь мы НЕ делаем reboot.
# Здесь мы превращаем грязный ввод пользователя в чистый список хостов.

# %%
#test data
RAW_HOSTS = "  ws-k534d, WS-K534F ,, ws-k534d , TEST-PC, "

# %%
def normalize_hosts(raw: str) -> list[str]:
        """
    Принимает грязную строку с хостами и возвращает чистый список хостов.

    Правила:
    1. Разделить по запятым.
    2. Убрать пробелы по краям.
    3. Привести к верхнему регистру.
    4. Удалить пустые элементы.
    5. Удалить дубли, сохранив порядок.
    """

    # TODO: split raw by comma
    
    
    # TODO: strip each host
    # TODO: upper each host
    # TODO: remove empty strings
    # TODO: remove duplicates but preserve order
